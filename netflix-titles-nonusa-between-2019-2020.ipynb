# %%
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=UserWarning)

# %% [markdown]
# ## Importing CSV

# %%
netflix_db = pd.read_csv('NetFlix.csv')

# %% [markdown]
# ## Turning date_added into datetime

# %%
netflix_db['date_added'] = pd.to_datetime(netflix_db['date_added'])
